# %%
# !pip install nibabel matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: nibabel in c:\users\clari\appdata\roaming\python\python310\site-packages (5.3.2)
# Requirement already satisfied: matplotlib in c:\users\clari\appdata\roaming\python\python310\site-packages (3.10.0)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\clari\appdata\roaming\python\python310\site-packages (from nibabel) (4.12.2)
# Requirement already satisfied: numpy>=1.22 in c:\users\clari\appdata\roaming\python\python310\site-packages (from nibabel) (2.2.1)
# Requirement already satisfied: importlib-resources>=5.12 in c:\users\clari\appdata\roaming\python\python310\site-packages (from nibabel) (6.5.2)
# Requirement already satisfied: packaging>=20 in c:\users\clari\appdata\roaming\python\python310\site-packages (from nibabel) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\clari\appdata\roaming\python\python310\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\clari\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\clari\appdata\roaming\python\python310\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\clari\appdata\roaming\python\python310\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\clari\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\clari\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\clari\appdata\roaming\python\python310\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\clari\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install nibabel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: nibabel in c:\users\clari\appdata\roaming\python\python312\site-packages (5.3.2)
# Requirement already satisfied: numpy>=1.22 in c:\users\clari\appdata\roaming\python\python312\site-packages (from nibabel) (2.0.2)
# Requirement already satisfied: packaging>=20 in c:\users\clari\appdata\roaming\python\python312\site-packages (from nibabel) (24.2)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\clari\appdata\roaming\python\python312\site-packages (from nibabel) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.10.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.55.3-cp312-cp312-win_amd64.whl.metadata (168 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\clari\appdata\roaming\python\python312\site-packages (from matplotlib) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.1.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\clari\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\clari\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.0-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.0 MB 6.3 MB/s eta 0:00:02
#    ------------------------------------ --- 7.3/8.0 MB 20.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 19.9 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.3-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 25.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Downloading pillow-11.1.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 37.5 MB/s eta 0:00:00
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.3 kiwisolver-1.4.8 matplotlib-3.10.0 pillow-11.1.0 pyparsing-3.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Path to your NIfTI file
file_path = r'BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData\BraTS20_Training_001\BraTS20_Training_001_flair.nii'
# Load the NIfTI file
img = nib.load(file_path)

# Get the image data (in NumPy array form)
img_data = img.get_fdata()

# Check the shape of the data (this should give you an idea of the dimensions)
print("Image shape:", img_data.shape)
# Out:
# Image shape: (240, 240, 155)

# %%
pip install ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: ipywidgets in c:\users\clari\appdata\roaming\python\python312\site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in c:\users\clari\appdata\roaming\python\python312\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from ipywidgets) (8.31.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\clari\appdata\roaming\python\python312\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\clari\appdata\roaming\python\python312\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: colorama in c:\users\clari\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\clari\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\clari\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\clari\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\clari\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\clari\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\clari\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\clari\appdata\roaming\python\python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\clari\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\clari\appdata\roaming\python\python312\site-packages (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# Path to the directory you want to inspect
directory_path = r'BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData'

# List all subdirectories and files
subdirs = [d for d in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, d))]

print("Subdirectories:")
for subdir in subdirs:
    print(subdir)
# Out:
# Subdirectories:
# BraTS20_Training_001
# BraTS20_Training_002
# BraTS20_Training_003
# BraTS20_Training_004
# BraTS20_Training_005
# BraTS20_Training_006
# BraTS20_Training_007
# BraTS20_Training_008
# BraTS20_Training_009
# BraTS20_Training_010
# BraTS20_Training_011
# BraTS20_Training_012
# BraTS20_Training_013
# BraTS20_Training_014
# BraTS20_Training_015
# BraTS20_Training_016
# BraTS20_Training_017
# BraTS20_Training_018
# BraTS20_Training_019
# BraTS20_Training_020
# BraTS20_Training_021
# BraTS20_Training_022
# BraTS20_Training_023
# BraTS20_Training_024
# BraTS20_Training_025
# BraTS20_Training_026
# BraTS20_Training_027
# BraTS20_Training_028
# BraTS20_Training_029
# BraTS20_Training_030
# BraTS20_Training_031
# BraTS20_Training_032
# BraTS20_Training_033
# BraTS20_Training_034
# BraTS20_Training_035
# BraTS20_Training_036
# BraTS20_Training_037
# BraTS20_Training_038
# BraTS20_Training_039
# BraTS20_Training_040
# BraTS20_Training_041
# BraTS20_Training_042
# BraTS20_Training_043
# BraTS20_Training_044
# BraTS20_Training_045
# BraTS20_Training_046
# BraTS20_Training_047
# BraTS20_Training_048
# BraTS20_Training_049
# BraTS20_Training_050
# BraTS20_Training_051
# BraTS20_Training_052
# BraTS20_Training_053
# BraTS20_Training_054
# BraTS20_Training_055
# BraTS20_Training_056
# BraTS20_Training_057
# BraTS20_Training_058
# BraTS20_Training_059
# BraTS20_Training_060
# BraTS20_Training_061
# BraTS20_Training_062
# BraTS20_Training_063
# BraTS20_Training_064
# BraTS20_Training_065
# BraTS20_Training_066
# BraTS20_Training_067
# BraTS20_Training_068
# BraTS20_Training_069
# BraTS20_Training_070
# BraTS20_Training_071
# BraTS20_Training_072
# BraTS20_Training_073
# BraTS20_Training_074
# BraTS20_Training_075
# BraTS20_Training_076
# BraTS20_Training_077
# BraTS20_Training_078
# BraTS20_Training_079
# BraTS20_Training_080
# BraTS20_Training_081
# BraTS20_Training_082
# BraTS20_Training_083
# BraTS20_Training_084
# BraTS20_Training_085
# BraTS20_Training_086
# BraTS20_Training_087
# BraTS20_Training_088
# BraTS20_Training_089
# BraTS20_Training_090
# BraTS20_Training_091
# BraTS20_Training_092
# BraTS20_Training_093
# BraTS20_Training_094
# BraTS20_Training_095
# BraTS20_Training_096
# BraTS20_Training_097
# BraTS20_Training_098
# BraTS20_Training_099
# BraTS20_Training_100
# BraTS20_Training_101
# BraTS20_Training_102
# BraTS20_Training_103
# BraTS20_Training_104
# BraTS20_Training_105
# BraTS20_Training_106
# BraTS20_Training_107
# BraTS20_Training_108
# BraTS20_Training_109
# BraTS20_Training_110
# BraTS20_Training_111
# BraTS20_Training_112
# BraTS20_Training_113
# BraTS20_Training_114
# BraTS20_Training_115
# BraTS20_Training_116
# BraTS20_Training_117
# BraTS20_Training_118
# BraTS20_Training_119
# BraTS20_Training_120
# BraTS20_Training_121
# BraTS20_Training_122
# BraTS20_Training_123
# BraTS20_Training_124
# BraTS20_Training_125
# BraTS20_Training_126
# BraTS20_Training_127
# BraTS20_Training_128
# BraTS20_Training_129
# BraTS20_Training_130
# BraTS20_Training_131
# BraTS20_Training_132
# BraTS20_Training_133
# BraTS20_Training_134
# BraTS20_Training_135
# BraTS20_Training_136
# BraTS20_Training_137
# BraTS20_Training_138
# BraTS20_Training_139
# BraTS20_Training_140
# BraTS20_Training_141
# BraTS20_Training_142
# BraTS20_Training_143
# BraTS20_Training_144
# BraTS20_Training_145
# BraTS20_Training_146
# BraTS20_Training_147
# BraTS20_Training_148
# BraTS20_Training_149
# BraTS20_Training_150
# BraTS20_Training_151
# BraTS20_Training_152
# BraTS20_Training_153
# BraTS20_Training_154
# BraTS20_Training_155
# BraTS20_Training_156
# BraTS20_Training_157
# BraTS20_Training_158
# BraTS20_Training_159
# BraTS20_Training_160
# BraTS20_Training_161
# BraTS20_Training_162
# BraTS20_Training_163
# BraTS20_Training_164
# BraTS20_Training_165
# BraTS20_Training_166
# BraTS20_Training_167
# BraTS20_Training_168
# BraTS20_Training_169
# BraTS20_Training_170
# BraTS20_Training_171
# BraTS20_Training_172
# BraTS20_Training_173
# BraTS20_Training_174
# BraTS20_Training_175
# BraTS20_Training_176
# BraTS20_Training_177
# BraTS20_Training_178
# BraTS20_Training_179
# BraTS20_Training_180
# BraTS20_Training_181
# BraTS20_Training_182
# BraTS20_Training_183
# BraTS20_Training_184
# BraTS20_Training_185
# BraTS20_Training_186
# BraTS20_Training_187
# BraTS20_Training_188
# BraTS20_Training_189
# BraTS20_Training_190
# BraTS20_Training_191
# BraTS20_Training_192
# BraTS20_Training_193
# BraTS20_Training_194
# BraTS20_Training_195
# BraTS20_Training_196
# BraTS20_Training_197
# BraTS20_Training_198
# BraTS20_Training_199
# BraTS20_Training_200
# BraTS20_Training_201
# BraTS20_Training_202
# BraTS20_Training_203
# BraTS20_Training_204
# BraTS20_Training_205
# BraTS20_Training_206
# BraTS20_Training_207
# BraTS20_Training_208
# BraTS20_Training_209
# BraTS20_Training_210
# BraTS20_Training_211
# BraTS20_Training_212
# BraTS20_Training_213
# BraTS20_Training_214
# BraTS20_Training_215
# BraTS20_Training_216
# BraTS20_Training_217
# BraTS20_Training_218
# BraTS20_Training_219
# BraTS20_Training_220
# BraTS20_Training_221
# BraTS20_Training_222
# BraTS20_Training_223
# BraTS20_Training_224
# BraTS20_Training_225
# BraTS20_Training_226
# BraTS20_Training_227
# BraTS20_Training_228
# BraTS20_Training_229
# BraTS20_Training_230
# BraTS20_Training_231
# BraTS20_Training_232
# BraTS20_Training_233
# BraTS20_Training_234
# BraTS20_Training_235
# BraTS20_Training_236
# BraTS20_Training_237
# BraTS20_Training_238
# BraTS20_Training_239
# BraTS20_Training_240
# BraTS20_Training_241
# BraTS20_Training_242
# BraTS20_Training_243
# BraTS20_Training_244
# BraTS20_Training_245
# BraTS20_Training_246
# BraTS20_Training_247
# BraTS20_Training_248
# BraTS20_Training_249
# BraTS20_Training_250
# BraTS20_Training_251
# BraTS20_Training_252
# BraTS20_Training_253
# BraTS20_Training_254
# BraTS20_Training_255
# BraTS20_Training_256
# BraTS20_Training_257
# BraTS20_Training_258
# BraTS20_Training_259
# BraTS20_Training_260
# BraTS20_Training_261
# BraTS20_Training_262
# BraTS20_Training_263
# BraTS20_Training_264
# BraTS20_Training_265
# BraTS20_Training_266
# BraTS20_Training_267
# BraTS20_Training_268
# BraTS20_Training_269
# BraTS20_Training_270
# BraTS20_Training_271
# BraTS20_Training_272
# BraTS20_Training_273
# BraTS20_Training_274
# BraTS20_Training_275
# BraTS20_Training_276
# BraTS20_Training_277
# BraTS20_Training_278
# BraTS20_Training_279
# BraTS20_Training_280
# BraTS20_Training_281
# BraTS20_Training_282
# BraTS20_Training_283
# BraTS20_Training_284
# BraTS20_Training_285
# BraTS20_Training_286
# BraTS20_Training_287
# BraTS20_Training_288
# BraTS20_Training_289
# BraTS20_Training_290
# BraTS20_Training_291
# BraTS20_Training_292
# BraTS20_Training_293
# BraTS20_Training_294
# BraTS20_Training_295
# BraTS20_Training_296
# BraTS20_Training_297
# BraTS20_Training_298
# BraTS20_Training_299
# BraTS20_Training_300
# BraTS20_Training_301
# BraTS20_Training_302
# BraTS20_Training_303
# BraTS20_Training_304
# BraTS20_Training_305
# BraTS20_Training_306
# BraTS20_Training_307
# BraTS20_Training_308
# BraTS20_Training_309
# BraTS20_Training_310
# BraTS20_Training_311
# BraTS20_Training_312
# BraTS20_Training_313
# BraTS20_Training_314
# BraTS20_Training_315
# BraTS20_Training_316
# BraTS20_Training_317
# BraTS20_Training_318
# BraTS20_Training_319
# BraTS20_Training_320
# BraTS20_Training_321
# BraTS20_Training_322
# BraTS20_Training_323
# BraTS20_Training_324
# BraTS20_Training_325
# BraTS20_Training_326
# BraTS20_Training_327
# BraTS20_Training_328
# BraTS20_Training_329
# BraTS20_Training_330
# BraTS20_Training_331
# BraTS20_Training_332
# BraTS20_Training_333
# BraTS20_Training_334
# BraTS20_Training_335
# BraTS20_Training_336
# BraTS20_Training_337
# BraTS20_Training_338
# BraTS20_Training_339
# BraTS20_Training_340
# BraTS20_Training_341
# BraTS20_Training_342
# BraTS20_Training_343
# BraTS20_Training_344
# BraTS20_Training_345
# BraTS20_Training_346
# BraTS20_Training_347
# BraTS20_Training_348
# BraTS20_Training_349
# BraTS20_Training_350
# BraTS20_Training_351
# BraTS20_Training_352
# BraTS20_Training_353
# BraTS20_Training_354
# BraTS20_Training_355
# BraTS20_Training_356
# BraTS20_Training_357
# BraTS20_Training_358
# BraTS20_Training_359
# BraTS20_Training_360
# BraTS20_Training_361
# BraTS20_Training_362
# BraTS20_Training_363
# BraTS20_Training_364
# BraTS20_Training_365
# BraTS20_Training_366
# BraTS20_Training_367
# BraTS20_Training_368
# BraTS20_Training_369
# <>:4: SyntaxWarning: invalid escape sequence '\M'
# <>:4: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\clari\AppData\Local\Temp\ipykernel_16344\1995946198.py:4: SyntaxWarning: invalid escape sequence '\M'
#   directory_path = 'BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData'

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: tensorflow in c:\users\clari\appdata\roaming\python\python312\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.69.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\clari\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\clari\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\clari\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)

# %%
pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: keras in c:\users\clari\appdata\roaming\python\python312\site-packages (3.8.0)
# Requirement already satisfied: absl-py in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras) (2.0.2)
# Requirement already satisfied: rich in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras) (0.13.1)
# Requirement already satisfied: ml-dtypes in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras) (24.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
# %pip install tifffile
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: tifffile in c:\users\clari\appdata\roaming\python\python312\site-packages (2024.12.12)
# Requirement already satisfied: numpy in c:\users\clari\appdata\roaming\python\python312\site-packages (from tifffile) (2.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: scikit-learn in c:\users\clari\appdata\roaming\python\python312\site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\clari\appdata\roaming\python\python312\site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.15.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import nibabel as nib
import glob
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from tifffile import imsave

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
TRAIN_DATASET_PATH = r'BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData'

# %%
test_image_flair=nib.load(TRAIN_DATASET_PATH + '/BraTS20_Training_355/BraTS20_Training_355_flair.nii').get_fdata() # Added a forward slash / to the path
print(test_image_flair.max())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 test_image_flair=nib.load(TRAIN_DATASET_PATH + '/BraTS20_Training_355/BraTS20_Training_355_flair.nii').get_fdata() # Added a forward slash / to the path
#       2 print(test_image_flair.max())
#
# NameError: name 'nib' is not defined

# %%
test_image_flair=scaler.fit_transform(test_image_flair.reshape(-1, test_image_flair.shape[-1])).reshape(test_image_flair.shape)
test_image_t1=nib.load(TRAIN_DATASET_PATH + '/BraTS20_Training_355/BraTS20_Training_355_t1.nii').get_fdata()
test_image_t1=scaler.fit_transform(test_image_t1.reshape(-1, test_image_t1.shape[-1])).reshape(test_image_t1.shape)

test_image_t1ce=nib.load(TRAIN_DATASET_PATH + '/BraTS20_Training_355/BraTS20_Training_355_t1ce.nii').get_fdata()
test_image_t1ce=scaler.fit_transform(test_image_t1ce.reshape(-1, test_image_t1ce.shape[-1])).reshape(test_image_t1ce.shape)

test_image_t2=nib.load(TRAIN_DATASET_PATH + '/BraTS20_Training_355/BraTS20_Training_355_t2.nii').get_fdata()
test_image_t2=scaler.fit_transform(test_image_t2.reshape(-1, test_image_t2.shape[-1])).reshape(test_image_t2.shape)

test_mask=nib.load(TRAIN_DATASET_PATH + '/BraTS20_Training_355/BraTS20_Training_355_seg.nii').get_fdata()
test_mask=test_mask.astype(np.uint8)

print(np.unique(test_mask))  #0, 1, 2, 4 (Need to reencode to 0, 1, 2, 3)
test_mask[test_mask==4] = 3  #Reassign mask values 4 to 3
print(np.unique(test_mask))
# Out:
# [0 1 2 4]
# [0 1 2 3]

# %%
import random
n_slice=random.randint(0, test_mask.shape[2])

plt.figure(figsize=(12, 8))

plt.subplot(231)
plt.imshow(test_image_flair[:,:,n_slice], cmap='gray')
plt.title('Image flair')
plt.subplot(232)
plt.imshow(test_image_t1[:,:,n_slice], cmap='gray')
plt.title('Image t1')
plt.subplot(233)
plt.imshow(test_image_t1ce[:,:,n_slice], cmap='gray')
plt.title('Image t1ce')
plt.subplot(234)
plt.imshow(test_image_t2[:,:,n_slice], cmap='gray')
plt.title('Image t2')
plt.subplot(235)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %% [markdown]
# Combining and Cropping

# %%
combined_x = np.stack([test_image_flair, test_image_t1ce, test_image_t2], axis=3)

#Crop to a size to be divisible by 64 so we can later extract 64x64x64 patches.
#cropping x, y, and z
#combined_x=combined_x[24:216, 24:216, 13:141]

combined_x=combined_x[56:184, 56:184, 13:141] #Crop to 128x128x128x4

#Do the same for mask
test_mask = test_mask[56:184, 56:184, 13:141]

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(combined_x[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(combined_x[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(combined_x[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
t2_list = sorted(glob.glob(r'BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData/*/*t2.nii'))
t1ce_list = sorted(glob.glob(r'BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData/*/*t1ce.nii'))
flair_list = sorted(glob.glob(r'BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData/*/*flair.nii'))
mask_list = sorted(glob.glob(r'BraTS2020_TrainingData\MICCAI_BraTS2020_TrainingData/*/*seg.nii'))

# %%
t1ce_list
# Out:
# ['BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_001\\BraTS20_Training_001_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_002\\BraTS20_Training_002_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_003\\BraTS20_Training_003_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_004\\BraTS20_Training_004_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_005\\BraTS20_Training_005_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_006\\BraTS20_Training_006_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_007\\BraTS20_Training_007_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_008\\BraTS20_Training_008_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_009\\BraTS20_Training_009_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_010\\BraTS20_Training_010_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_011\\BraTS20_Training_011_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_012\\BraTS20_Training_012_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_013\\BraTS20_Training_013_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_014\\BraTS20_Training_014_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_015\\BraTS20_Training_015_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_016\\BraTS20_Training_016_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_017\\BraTS20_Training_017_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_018\\BraTS20_Training_018_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_019\\BraTS20_Training_019_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_020\\BraTS20_Training_020_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_021\\BraTS20_Training_021_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_022\\BraTS20_Training_022_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_023\\BraTS20_Training_023_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_024\\BraTS20_Training_024_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_025\\BraTS20_Training_025_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_026\\BraTS20_Training_026_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_027\\BraTS20_Training_027_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_028\\BraTS20_Training_028_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_029\\BraTS20_Training_029_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_030\\BraTS20_Training_030_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_031\\BraTS20_Training_031_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_032\\BraTS20_Training_032_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_033\\BraTS20_Training_033_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_034\\BraTS20_Training_034_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_035\\BraTS20_Training_035_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_036\\BraTS20_Training_036_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_037\\BraTS20_Training_037_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_038\\BraTS20_Training_038_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_039\\BraTS20_Training_039_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_040\\BraTS20_Training_040_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_041\\BraTS20_Training_041_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_042\\BraTS20_Training_042_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_043\\BraTS20_Training_043_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_044\\BraTS20_Training_044_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_045\\BraTS20_Training_045_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_046\\BraTS20_Training_046_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_047\\BraTS20_Training_047_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_048\\BraTS20_Training_048_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_049\\BraTS20_Training_049_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_050\\BraTS20_Training_050_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_051\\BraTS20_Training_051_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_052\\BraTS20_Training_052_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_053\\BraTS20_Training_053_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_054\\BraTS20_Training_054_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_055\\BraTS20_Training_055_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_056\\BraTS20_Training_056_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_057\\BraTS20_Training_057_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_058\\BraTS20_Training_058_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_059\\BraTS20_Training_059_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_060\\BraTS20_Training_060_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_061\\BraTS20_Training_061_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_062\\BraTS20_Training_062_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_063\\BraTS20_Training_063_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_064\\BraTS20_Training_064_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_065\\BraTS20_Training_065_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_066\\BraTS20_Training_066_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_067\\BraTS20_Training_067_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_068\\BraTS20_Training_068_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_069\\BraTS20_Training_069_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_070\\BraTS20_Training_070_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_071\\BraTS20_Training_071_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_072\\BraTS20_Training_072_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_073\\BraTS20_Training_073_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_074\\BraTS20_Training_074_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_075\\BraTS20_Training_075_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_076\\BraTS20_Training_076_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_077\\BraTS20_Training_077_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_078\\BraTS20_Training_078_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_079\\BraTS20_Training_079_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_080\\BraTS20_Training_080_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_081\\BraTS20_Training_081_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_082\\BraTS20_Training_082_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_083\\BraTS20_Training_083_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_084\\BraTS20_Training_084_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_085\\BraTS20_Training_085_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_086\\BraTS20_Training_086_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_087\\BraTS20_Training_087_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_088\\BraTS20_Training_088_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_089\\BraTS20_Training_089_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_090\\BraTS20_Training_090_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_091\\BraTS20_Training_091_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_092\\BraTS20_Training_092_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_093\\BraTS20_Training_093_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_094\\BraTS20_Training_094_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_095\\BraTS20_Training_095_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_096\\BraTS20_Training_096_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_097\\BraTS20_Training_097_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_098\\BraTS20_Training_098_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_099\\BraTS20_Training_099_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_100\\BraTS20_Training_100_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_101\\BraTS20_Training_101_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_102\\BraTS20_Training_102_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_103\\BraTS20_Training_103_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_104\\BraTS20_Training_104_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_105\\BraTS20_Training_105_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_106\\BraTS20_Training_106_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_107\\BraTS20_Training_107_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_108\\BraTS20_Training_108_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_109\\BraTS20_Training_109_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_110\\BraTS20_Training_110_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_111\\BraTS20_Training_111_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_112\\BraTS20_Training_112_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_113\\BraTS20_Training_113_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_114\\BraTS20_Training_114_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_115\\BraTS20_Training_115_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_116\\BraTS20_Training_116_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_117\\BraTS20_Training_117_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_118\\BraTS20_Training_118_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_119\\BraTS20_Training_119_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_120\\BraTS20_Training_120_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_121\\BraTS20_Training_121_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_122\\BraTS20_Training_122_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_123\\BraTS20_Training_123_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_124\\BraTS20_Training_124_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_125\\BraTS20_Training_125_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_126\\BraTS20_Training_126_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_127\\BraTS20_Training_127_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_128\\BraTS20_Training_128_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_129\\BraTS20_Training_129_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_130\\BraTS20_Training_130_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_131\\BraTS20_Training_131_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_132\\BraTS20_Training_132_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_133\\BraTS20_Training_133_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_134\\BraTS20_Training_134_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_135\\BraTS20_Training_135_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_136\\BraTS20_Training_136_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_137\\BraTS20_Training_137_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_138\\BraTS20_Training_138_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_139\\BraTS20_Training_139_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_140\\BraTS20_Training_140_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_141\\BraTS20_Training_141_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_142\\BraTS20_Training_142_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_143\\BraTS20_Training_143_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_144\\BraTS20_Training_144_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_145\\BraTS20_Training_145_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_146\\BraTS20_Training_146_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_147\\BraTS20_Training_147_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_148\\BraTS20_Training_148_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_149\\BraTS20_Training_149_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_150\\BraTS20_Training_150_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_151\\BraTS20_Training_151_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_152\\BraTS20_Training_152_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_153\\BraTS20_Training_153_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_154\\BraTS20_Training_154_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_155\\BraTS20_Training_155_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_156\\BraTS20_Training_156_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_157\\BraTS20_Training_157_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_158\\BraTS20_Training_158_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_159\\BraTS20_Training_159_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_160\\BraTS20_Training_160_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_161\\BraTS20_Training_161_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_162\\BraTS20_Training_162_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_163\\BraTS20_Training_163_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_164\\BraTS20_Training_164_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_165\\BraTS20_Training_165_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_166\\BraTS20_Training_166_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_167\\BraTS20_Training_167_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_168\\BraTS20_Training_168_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_169\\BraTS20_Training_169_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_170\\BraTS20_Training_170_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_171\\BraTS20_Training_171_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_172\\BraTS20_Training_172_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_173\\BraTS20_Training_173_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_174\\BraTS20_Training_174_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_175\\BraTS20_Training_175_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_176\\BraTS20_Training_176_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_177\\BraTS20_Training_177_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_178\\BraTS20_Training_178_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_179\\BraTS20_Training_179_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_180\\BraTS20_Training_180_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_181\\BraTS20_Training_181_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_182\\BraTS20_Training_182_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_183\\BraTS20_Training_183_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_184\\BraTS20_Training_184_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_185\\BraTS20_Training_185_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_186\\BraTS20_Training_186_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_187\\BraTS20_Training_187_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_188\\BraTS20_Training_188_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_189\\BraTS20_Training_189_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_190\\BraTS20_Training_190_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_191\\BraTS20_Training_191_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_192\\BraTS20_Training_192_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_193\\BraTS20_Training_193_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_194\\BraTS20_Training_194_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_195\\BraTS20_Training_195_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_196\\BraTS20_Training_196_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_197\\BraTS20_Training_197_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_198\\BraTS20_Training_198_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_199\\BraTS20_Training_199_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_200\\BraTS20_Training_200_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_201\\BraTS20_Training_201_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_202\\BraTS20_Training_202_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_203\\BraTS20_Training_203_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_204\\BraTS20_Training_204_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_205\\BraTS20_Training_205_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_206\\BraTS20_Training_206_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_207\\BraTS20_Training_207_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_208\\BraTS20_Training_208_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_209\\BraTS20_Training_209_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_210\\BraTS20_Training_210_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_211\\BraTS20_Training_211_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_212\\BraTS20_Training_212_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_213\\BraTS20_Training_213_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_214\\BraTS20_Training_214_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_215\\BraTS20_Training_215_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_216\\BraTS20_Training_216_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_217\\BraTS20_Training_217_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_218\\BraTS20_Training_218_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_219\\BraTS20_Training_219_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_220\\BraTS20_Training_220_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_221\\BraTS20_Training_221_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_222\\BraTS20_Training_222_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_223\\BraTS20_Training_223_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_224\\BraTS20_Training_224_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_225\\BraTS20_Training_225_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_226\\BraTS20_Training_226_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_227\\BraTS20_Training_227_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_228\\BraTS20_Training_228_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_229\\BraTS20_Training_229_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_230\\BraTS20_Training_230_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_231\\BraTS20_Training_231_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_232\\BraTS20_Training_232_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_233\\BraTS20_Training_233_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_234\\BraTS20_Training_234_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_235\\BraTS20_Training_235_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_236\\BraTS20_Training_236_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_237\\BraTS20_Training_237_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_238\\BraTS20_Training_238_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_239\\BraTS20_Training_239_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_240\\BraTS20_Training_240_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_241\\BraTS20_Training_241_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_242\\BraTS20_Training_242_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_243\\BraTS20_Training_243_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_244\\BraTS20_Training_244_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_245\\BraTS20_Training_245_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_246\\BraTS20_Training_246_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_247\\BraTS20_Training_247_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_248\\BraTS20_Training_248_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_249\\BraTS20_Training_249_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_250\\BraTS20_Training_250_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_251\\BraTS20_Training_251_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_252\\BraTS20_Training_252_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_253\\BraTS20_Training_253_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_254\\BraTS20_Training_254_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_255\\BraTS20_Training_255_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_256\\BraTS20_Training_256_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_257\\BraTS20_Training_257_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_258\\BraTS20_Training_258_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_259\\BraTS20_Training_259_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_260\\BraTS20_Training_260_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_261\\BraTS20_Training_261_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_262\\BraTS20_Training_262_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_263\\BraTS20_Training_263_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_264\\BraTS20_Training_264_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_265\\BraTS20_Training_265_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_266\\BraTS20_Training_266_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_267\\BraTS20_Training_267_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_268\\BraTS20_Training_268_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_269\\BraTS20_Training_269_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_270\\BraTS20_Training_270_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_271\\BraTS20_Training_271_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_272\\BraTS20_Training_272_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_273\\BraTS20_Training_273_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_274\\BraTS20_Training_274_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_275\\BraTS20_Training_275_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_276\\BraTS20_Training_276_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_277\\BraTS20_Training_277_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_278\\BraTS20_Training_278_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_279\\BraTS20_Training_279_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_280\\BraTS20_Training_280_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_281\\BraTS20_Training_281_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_282\\BraTS20_Training_282_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_283\\BraTS20_Training_283_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_284\\BraTS20_Training_284_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_285\\BraTS20_Training_285_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_286\\BraTS20_Training_286_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_287\\BraTS20_Training_287_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_288\\BraTS20_Training_288_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_289\\BraTS20_Training_289_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_290\\BraTS20_Training_290_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_291\\BraTS20_Training_291_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_292\\BraTS20_Training_292_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_293\\BraTS20_Training_293_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_294\\BraTS20_Training_294_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_295\\BraTS20_Training_295_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_296\\BraTS20_Training_296_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_297\\BraTS20_Training_297_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_298\\BraTS20_Training_298_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_299\\BraTS20_Training_299_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_300\\BraTS20_Training_300_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_301\\BraTS20_Training_301_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_302\\BraTS20_Training_302_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_303\\BraTS20_Training_303_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_304\\BraTS20_Training_304_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_305\\BraTS20_Training_305_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_306\\BraTS20_Training_306_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_307\\BraTS20_Training_307_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_308\\BraTS20_Training_308_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_309\\BraTS20_Training_309_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_310\\BraTS20_Training_310_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_311\\BraTS20_Training_311_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_312\\BraTS20_Training_312_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_313\\BraTS20_Training_313_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_314\\BraTS20_Training_314_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_315\\BraTS20_Training_315_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_316\\BraTS20_Training_316_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_317\\BraTS20_Training_317_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_318\\BraTS20_Training_318_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_319\\BraTS20_Training_319_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_320\\BraTS20_Training_320_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_321\\BraTS20_Training_321_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_322\\BraTS20_Training_322_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_323\\BraTS20_Training_323_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_324\\BraTS20_Training_324_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_325\\BraTS20_Training_325_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_326\\BraTS20_Training_326_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_327\\BraTS20_Training_327_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_328\\BraTS20_Training_328_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_329\\BraTS20_Training_329_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_330\\BraTS20_Training_330_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_331\\BraTS20_Training_331_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_332\\BraTS20_Training_332_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_333\\BraTS20_Training_333_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_334\\BraTS20_Training_334_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_335\\BraTS20_Training_335_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_336\\BraTS20_Training_336_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_337\\BraTS20_Training_337_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_338\\BraTS20_Training_338_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_339\\BraTS20_Training_339_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_340\\BraTS20_Training_340_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_341\\BraTS20_Training_341_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_342\\BraTS20_Training_342_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_343\\BraTS20_Training_343_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_344\\BraTS20_Training_344_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_345\\BraTS20_Training_345_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_346\\BraTS20_Training_346_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_347\\BraTS20_Training_347_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_348\\BraTS20_Training_348_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_349\\BraTS20_Training_349_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_350\\BraTS20_Training_350_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_351\\BraTS20_Training_351_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_352\\BraTS20_Training_352_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_353\\BraTS20_Training_353_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_354\\BraTS20_Training_354_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_355\\BraTS20_Training_355_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_356\\BraTS20_Training_356_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_357\\BraTS20_Training_357_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_358\\BraTS20_Training_358_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_359\\BraTS20_Training_359_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_360\\BraTS20_Training_360_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_361\\BraTS20_Training_361_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_362\\BraTS20_Training_362_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_363\\BraTS20_Training_363_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_364\\BraTS20_Training_364_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_365\\BraTS20_Training_365_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_366\\BraTS20_Training_366_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_367\\BraTS20_Training_367_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_368\\BraTS20_Training_368_t1ce.nii',
#  'BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\BraTS20_Training_369\\BraTS20_Training_369_t1ce.nii']

# %%
for img in range(len(t2_list)):   #Using t1_list as all lists are of same size
    print("Now preparing image and masks number: ", img)

    temp_image_t2=nib.load(t2_list[img]).get_fdata()
    temp_image_t2=scaler.fit_transform(temp_image_t2.reshape(-1, temp_image_t2.shape[-1])).reshape(temp_image_t2.shape)

    temp_image_t1ce=nib.load(t1ce_list[img]).get_fdata()
    temp_image_t1ce=scaler.fit_transform(temp_image_t1ce.reshape(-1, temp_image_t1ce.shape[-1])).reshape(temp_image_t1ce.shape)

    temp_image_flair=nib.load(flair_list[img]).get_fdata()
    temp_image_flair=scaler.fit_transform(temp_image_flair.reshape(-1, temp_image_flair.shape[-1])).reshape(temp_image_flair.shape)

    temp_mask=nib.load(mask_list[img]).get_fdata()
    temp_mask=temp_mask.astype(np.uint8)
    temp_mask[temp_mask==4] = 3  #Reassign mask values 4 to 3
    #print(np.unique(temp_mask))


    temp_combined_images = np.stack([temp_image_flair, temp_image_t1ce, temp_image_t2], axis=3)

    #Crop to a size to be divisible by 64 so we can later extract 64x64x64 patches.
    #cropping x, y, and z
    temp_combined_images=temp_combined_images[56:184, 56:184, 13:141]
    temp_mask = temp_mask[56:184, 56:184, 13:141]

    val, counts = np.unique(temp_mask, return_counts=True)

    if (1 - (counts[0]/counts.sum())) > 0.01:  #At least 1% useful volume with labels that are not 0
        print("Save Me")
        temp_mask= to_categorical(temp_mask, num_classes=4)
        np.save(r'\BraTS2020_TrainingData\input_data_3channels\images\image_'+str(img)+'.npy', temp_combined_images)
        np.save(r'\BraTS2020_TrainingData\input_data_3channels\masks\mask_'+str(img)+'.npy', temp_mask)

    else:
        print("I am useless")
# Out:
# Now preparing image and masks number:  0
# Save Me
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 31
#      29     print("Save Me")
#      30     temp_mask= to_categorical(temp_mask, num_classes=4)
# ---> 31     np.save(r'\BraTS2020_TrainingData\input_data_3channels\images\image_'+str(img)+'.npy', temp_combined_images)
#      32     np.save(r'\BraTS2020_TrainingData\input_data_3channels\masks\mask_'+str(img)+'.npy', temp_mask)
#      34 else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\_npyio_impl.py:570, in save(file, arr, allow_pickle, fix_imports)
#     568     if not file.endswith('.npy'):
#     569         file = file + '.npy'
# --> 570     file_ctx = open(file, "wb")
#     572 with file_ctx as fid:
#     573     arr = np.asanyarray(arr)
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\BraTS2020_TrainingData\\input_data_3channels\\images\\image_0.npy'

# %%
# Ensure necessary imports
import numpy as np
import nibabel as nib
import glob
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from tifffile import imsave
from sklearn.preprocessing import MinMaxScaler

# Assuming scaler is already defined in a previous cell
scaler = MinMaxScaler()

# Assuming t2_list, t1ce_list, flair_list, and mask_list are already defined in previous cells
for img in range(len(t2_list)):   # Using t1_list as all lists are of same size
	print("Now preparing image and masks number: ", img)

	temp_image_t2 = nib.load(t2_list[img]).get_fdata()
	temp_image_t2 = scaler.fit_transform(temp_image_t2.reshape(-1, temp_image_t2.shape[-1])).reshape(temp_image_t2.shape)

	temp_image_t1ce = nib.load(t1ce_list[img]).get_fdata()
	temp_image_t1ce = scaler.fit_transform(temp_image_t1ce.reshape(-1, temp_image_t1ce.shape[-1])).reshape(temp_image_t1ce.shape)

	temp_image_flair = nib.load(flair_list[img]).get_fdata()
	temp_image_flair = scaler.fit_transform(temp_image_flair.reshape(-1, temp_image_flair.shape[-1])).reshape(temp_image_flair.shape)

	temp_mask = nib.load(mask_list[img]).get_fdata()
	temp_mask = temp_mask.astype(np.uint8)
	temp_mask[temp_mask == 4] = 3  # Reassign mask values 4 to 3

	temp_combined_images = np.stack([temp_image_flair, temp_image_t1ce, temp_image_t2], axis=3)

	# Crop to a size to be divisible by 64 so we can later extract 64x64x64 patches.
	# cropping x, y, and z
	temp_combined_images = temp_combined_images[56:184, 56:184, 13:141]
	temp_mask = temp_mask[56:184, 56:184, 13:141]

	val, counts = np.unique(temp_mask, return_counts=True)

	if (1 - (counts[0] / counts.sum())) > 0.01:  # At least 1% useful volume with labels that are not 0
		print("Save Me")
		temp_mask = to_categorical(temp_mask, num_classes=4)
		np.save(r'BraTS2020_TrainingData/input_data_3channels/images/image_' + str(img) + '.npy', temp_combined_images)
		np.save(r'BraTS2020_TrainingData/input_data_3channels/masks/mask_' + str(img) + '.npy', temp_mask)
	else:
		print("I am useless")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      11 scaler = MinMaxScaler()
#      13 # Assuming t2_list, t1ce_list, flair_list, and mask_list are already defined in previous cells
# ---> 14 for img in range(len(t2_list)):   # Using t1_list as all lists are of same size
#      15 	print("Now preparing image and masks number: ", img)
#      17 	temp_image_t2 = nib.load(t2_list[img]).get_fdata()
#
# NameError: name 't2_list' is not defined

# %%
# %pip install split-folders
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import splitfolders  # or import split_folders

input_folder = r'BraTS2020_TrainingData\input_data_3channels'
output_folder = r'BraTS2020_TrainingData\input_data_128'
# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.75, .25), group_prefix=None)
# Out:
# Copying files: 688 files [01:16,  9.03 files/s]

# %%
import os
filepath = r'BraTS2020_TrainingData\input_data_3channels\images\image_23.npy'
print(os.path.exists(filepath))  # Check if file exists
print(os.access(filepath, os.R_OK))  # Check if file is readable
# Out:
# False
# False

# %%
def load_img(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):
        if (image_name.split('.')[1] == 'npy'):

            image = np.load(img_dir+image_name)
            image=image.astype(np.float32)
            images.append(image)
    images = np.array(images)

    return(images)

# %%
def imageLoader(img_dir, img_list, mask_dir, mask_list, batch_size):

    L = len(img_list)

    #keras needs the generator infinite, so we will use while true
    while True:

        batch_start = 0
        batch_end = batch_size

        while batch_start < L:
            limit = min(batch_end, L)

            X = load_img(img_dir, img_list[batch_start:limit])
            Y = load_img(mask_dir, mask_list[batch_start:limit])

            yield (X,Y) #a tuple with two numpy arrays with batch_size samples

            batch_start += batch_size
            batch_end += batch_size

# %%
from matplotlib import pyplot as plt
import random
import os
import numpy as np

train_img_dir = r"BraTS2020_TrainingData\input_data_128\train\images\\"
train_mask_dir = r"BraTS2020_TrainingData\input_data_128\train\masks\\"
train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

batch_size = 2

train_img_datagen = imageLoader(train_img_dir, train_img_list,
                                train_mask_dir, train_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
img, msk = train_img_datagen.__next__()


img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]
test_mask=np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
# %pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\clari\appdata\roaming\python\python312\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.69.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Collecting keras>=3.5.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached keras-3.8.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\clari\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\clari\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\clari\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# Using cached keras-3.8.0-py3-none-any.whl (1.3 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.3.3
#     Uninstalling keras-3.3.3:
#       Successfully uninstalled keras-3.3.3
# Successfully installed keras-3.8.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# segmentation-models-3d 1.1.1 requires keras==3.3.3, but you have keras 3.8.0 which is incompatible.

# %%
from keras.models import Model
from keras.layers import Input, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.metrics import MeanIoU

kernel_initializer =  'he_uniform' #Try others if you want


################################################################
def simple_unet_model(IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS, num_classes):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c1)
    p1 = MaxPooling3D((2, 2, 2))(c1)

    c2 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c2)
    p2 = MaxPooling3D((2, 2, 2))(c2)

    c3 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c3)
    p3 = MaxPooling3D((2, 2, 2))(c3)

    c4 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c4)
    p4 = MaxPooling3D(pool_size=(2, 2, 2))(c4)

    c5 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c5)

    #Expansive path
    u6 = Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c6)

    u7 = Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c7)

    u8 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c8)

    u9 = Conv3DTranspose(16, (2, 2, 2), strides=(2, 2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c9)

    outputs = Conv3D(num_classes, (1, 1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    #compile model outside of this function to make it flexible.
    model.summary()

    return model

#Test if everything is working ok.
model = simple_unet_model(128, 128, 128, 3, 4)
print(model.input_shape)
print(model.output_shape)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 128, 3)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d (Conv3D)     │ (None, 128, 128,  │      1,312 │ input_layer[0][0] │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ conv3d[0][0]      │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_1 (Conv3D)   │ (None, 128, 128,  │      6,928 │ dropout[0][0]     │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d       │ (None, 64, 64,    │          0 │ conv3d_1[0][0]    │
# │ (MaxPooling3D)      │ 64, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_2 (Conv3D)   │ (None, 64, 64,    │     13,856 │ max_pooling3d[0]… │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ conv3d_2[0][0]    │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_3 (Conv3D)   │ (None, 64, 64,    │     27,680 │ dropout_1[0][0]   │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_1     │ (None, 32, 32,    │          0 │ conv3d_3[0][0]    │
# │ (MaxPooling3D)      │ 32, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_4 (Conv3D)   │ (None, 32, 32,    │     55,360 │ max_pooling3d_1[… │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ conv3d_4[0][0]    │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_5 (Conv3D)   │ (None, 32, 32,    │    110,656 │ dropout_2[0][0]   │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_2     │ (None, 16, 16,    │          0 │ conv3d_5[0][0]    │
# │ (MaxPooling3D)      │ 16, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_6 (Conv3D)   │ (None, 16, 16,    │    221,312 │ max_pooling3d_2[… │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ conv3d_6[0][0]    │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_7 (Conv3D)   │ (None, 16, 16,    │    442,496 │ dropout_3[0][0]   │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_3     │ (None, 8, 8, 8,   │          0 │ conv3d_7[0][0]    │
# │ (MaxPooling3D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_8 (Conv3D)   │ (None, 8, 8, 8,   │    884,992 │ max_pooling3d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 8, 8, 8,   │          0 │ conv3d_8[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_9 (Conv3D)   │ (None, 8, 8, 8,   │  1,769,728 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose    │ (None, 16, 16,    │    262,272 │ conv3d_9[0][0]    │
# │ (Conv3DTranspose)   │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 16, 256)          │            │ conv3d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_10 (Conv3D)  │ (None, 16, 16,    │    884,864 │ concatenate[0][0] │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 16, 16,    │          0 │ conv3d_10[0][0]   │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_11 (Conv3D)  │ (None, 16, 16,    │    442,496 │ dropout_5[0][0]   │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_1  │ (None, 32, 32,    │     65,600 │ conv3d_11[0][0]   │
# │ (Conv3DTranspose)   │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 32, 128)          │            │ conv3d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_12 (Conv3D)  │ (None, 32, 32,    │    221,248 │ concatenate_1[0]… │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 32, 32,    │          0 │ conv3d_12[0][0]   │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_13 (Conv3D)  │ (None, 32, 32,    │    110,656 │ dropout_6[0][0]   │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_2  │ (None, 64, 64,    │     16,416 │ conv3d_13[0][0]   │
# │ (Conv3DTranspose)   │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 64, 64)           │            │ conv3d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_14 (Conv3D)  │ (None, 64, 64,    │     55,328 │ concatenate_2[0]… │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64, 64,    │          0 │ conv3d_14[0][0]   │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_15 (Conv3D)  │ (None, 64, 64,    │     27,680 │ dropout_7[0][0]   │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_3  │ (None, 128, 128,  │      4,112 │ conv3d_15[0][0]   │
# │ (Conv3DTranspose)   │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 128, 32)          │            │ conv3d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_16 (Conv3D)  │ (None, 128, 128,  │     13,840 │ concatenate_3[0]… │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 128, 128,  │          0 │ conv3d_16[0][0]   │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_17 (Conv3D)  │ (None, 128, 128,  │      6,928 │ dropout_8[0][0]   │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_18 (Conv3D)  │ (None, 128, 128,  │         68 │ conv3d_17[0][0]   │
# │                     │ 128, 4)           │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,645,828 (21.54 MB)
#  Trainable params: 5,645,828 (21.54 MB)
#  Non-trainable params: 0 (0.00 B)
# (None, 128, 128, 128, 3)
# (None, 128, 128, 128, 4)

# %%
import os
import numpy as np
#from custom_datagen import imageLoader
#import tensorflow as tf
import keras
from matplotlib import pyplot as plt
import glob
import random

# %%
train_img_dir = r"BraTS2020_TrainingData\input_data_128\train\images\\"
train_mask_dir = r"BraTS2020_TrainingData\input_data_128\train\masks\\"

val_img_dir = r"BraTS2020_TrainingData\input_data_128\val\images\\"
val_mask_dir = r"BraTS2020_TrainingData\input_data_128\val\masks\\"

train_img_list = sorted(os.listdir(train_img_dir))
train_mask_list = sorted(os.listdir(train_mask_dir))

val_img_list = sorted(os.listdir(val_img_dir))
val_mask_list = sorted(os.listdir(val_mask_dir))

# %%
batch_size = 2

train_img_datagen = imageLoader(train_img_dir, train_img_list,
                                train_mask_dir, train_mask_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list,
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
img, msk = train_img_datagen.__next__()

img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]
test_mask=np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
# %pip install segmentation-models-3D
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: segmentation-models-3D in c:\users\clari\appdata\roaming\python\python312\site-packages (1.1.1)
# Collecting keras==3.3.3 (from segmentation-models-3D)
#   Downloading keras-3.3.3-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: classification-models-3D==1.1.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from segmentation-models-3D) (1.1.0)
# Requirement already satisfied: absl-py in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras==3.3.3->segmentation-models-3D) (2.1.0)
# Requirement already satisfied: numpy in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras==3.3.3->segmentation-models-3D) (2.0.2)
# Requirement already satisfied: rich in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras==3.3.3->segmentation-models-3D) (13.9.4)
# Requirement already satisfied: namex in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras==3.3.3->segmentation-models-3D) (0.0.8)
# Requirement already satisfied: h5py in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras==3.3.3->segmentation-models-3D) (3.12.1)
# Requirement already satisfied: optree in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras==3.3.3->segmentation-models-3D) (0.13.1)
# Requirement already satisfied: ml-dtypes in c:\users\clari\appdata\roaming\python\python312\site-packages (from keras==3.3.3->segmentation-models-3D) (0.4.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from optree->keras==3.3.3->segmentation-models-3D) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from rich->keras==3.3.3->segmentation-models-3D) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\clari\appdata\roaming\python\python312\site-packages (from rich->keras==3.3.3->segmentation-models-3D) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\clari\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras==3.3.3->segmentation-models-3D) (0.1.2)
# Downloading keras-3.3.3-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ------------------ --------------------- 0.5/1.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 0.8/1.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 1.5 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.8.0
#     Uninstalling keras-3.8.0:
#       Successfully uninstalled keras-3.8.0
# Successfully installed keras-3.3.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.18.0 requires keras>=3.5.0, but you have keras 3.3.3 which is incompatible.

# %%
wt0, wt1, wt2, wt3 = 0.25,0.25,0.25,0.25
import segmentation_models_3D as sm
dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3]))
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = ['accuracy', sm.metrics.IOUScore(threshold=0.5)]

LR = 0.0001
optim = keras.optimizers.Adam(LR)
print(optim)
# Out:
# Segmentation Models: using `keras` framework.
# <keras.src.optimizers.adam.Adam object at 0x00000226A2234B30>

# %%
steps_per_epoch = len(train_img_list)//batch_size
val_steps_per_epoch = len(val_img_list)//batch_size


model = simple_unet_model(IMG_HEIGHT=128,
                          IMG_WIDTH=128,
                          IMG_DEPTH=128,
                          IMG_CHANNELS=3,
                          num_classes=4)

model.compile(optimizer = optim, loss=total_loss, metrics=metrics)
print(model.summary())

print(model.input_shape)
print(model.output_shape)
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 128, 3)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_83 (Conv3D)  │ (None, 128, 128,  │      1,312 │ input_layer_2[0]… │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 128, 128,  │          0 │ conv3d_83[0][0]   │
# │ (Dropout)           │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_84 (Conv3D)  │ (None, 128, 128,  │      6,928 │ dropout_18[0][0]  │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_8     │ (None, 64, 64,    │          0 │ conv3d_84[0][0]   │
# │ (MaxPooling3D)      │ 64, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_85 (Conv3D)  │ (None, 64, 64,    │     13,856 │ max_pooling3d_8[… │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 64, 64,    │          0 │ conv3d_85[0][0]   │
# │ (Dropout)           │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_86 (Conv3D)  │ (None, 64, 64,    │     27,680 │ dropout_19[0][0]  │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_9     │ (None, 32, 32,    │          0 │ conv3d_86[0][0]   │
# │ (MaxPooling3D)      │ 32, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_87 (Conv3D)  │ (None, 32, 32,    │     55,360 │ max_pooling3d_9[… │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 32, 32,    │          0 │ conv3d_87[0][0]   │
# │ (Dropout)           │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_88 (Conv3D)  │ (None, 32, 32,    │    110,656 │ dropout_20[0][0]  │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_10    │ (None, 16, 16,    │          0 │ conv3d_88[0][0]   │
# │ (MaxPooling3D)      │ 16, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_89 (Conv3D)  │ (None, 16, 16,    │    221,312 │ max_pooling3d_10… │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 16, 16,    │          0 │ conv3d_89[0][0]   │
# │ (Dropout)           │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_90 (Conv3D)  │ (None, 16, 16,    │    442,496 │ dropout_21[0][0]  │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_11    │ (None, 8, 8, 8,   │          0 │ conv3d_90[0][0]   │
# │ (MaxPooling3D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_91 (Conv3D)  │ (None, 8, 8, 8,   │    884,992 │ max_pooling3d_11… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 8, 8, 8,   │          0 │ conv3d_91[0][0]   │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_92 (Conv3D)  │ (None, 8, 8, 8,   │  1,769,728 │ dropout_22[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_8  │ (None, 16, 16,    │    262,272 │ conv3d_92[0][0]   │
# │ (Conv3DTranspose)   │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 16, 16,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 16, 256)          │            │ conv3d_90[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_93 (Conv3D)  │ (None, 16, 16,    │    884,864 │ concatenate_8[0]… │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 16, 16,    │          0 │ conv3d_93[0][0]   │
# │ (Dropout)           │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_94 (Conv3D)  │ (None, 16, 16,    │    442,496 │ dropout_23[0][0]  │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_9  │ (None, 32, 32,    │     65,600 │ conv3d_94[0][0]   │
# │ (Conv3DTranspose)   │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 32, 32,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 32, 128)          │            │ conv3d_88[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_95 (Conv3D)  │ (None, 32, 32,    │    221,248 │ concatenate_9[0]… │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 32, 32,    │          0 │ conv3d_95[0][0]   │
# │ (Dropout)           │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_96 (Conv3D)  │ (None, 32, 32,    │    110,656 │ dropout_24[0][0]  │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_10 │ (None, 64, 64,    │     16,416 │ conv3d_96[0][0]   │
# │ (Conv3DTranspose)   │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 64, 64,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 64, 64)           │            │ conv3d_86[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_97 (Conv3D)  │ (None, 64, 64,    │     55,328 │ concatenate_10[0… │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 64, 64,    │          0 │ conv3d_97[0][0]   │
# │ (Dropout)           │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_98 (Conv3D)  │ (None, 64, 64,    │     27,680 │ dropout_25[0][0]  │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_11 │ (None, 128, 128,  │      4,112 │ conv3d_98[0][0]   │
# │ (Conv3DTranspose)   │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 128, 128,  │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 128, 32)          │            │ conv3d_84[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_99 (Conv3D)  │ (None, 128, 128,  │     13,840 │ concatenate_11[0… │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 128, 128,  │          0 │ conv3d_99[0][0]   │
# │ (Dropout)           │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_100 (Conv3D) │ (None, 128, 128,  │      6,928 │ dropout_26[0][0]  │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_101 (Conv3D) │ (None, 128, 128,  │         68 │ conv3d_100[0][0]  │
# │                     │ 128, 4)           │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,645,828 (21.54 MB)
#  Trainable params: 5,645,828 (21.54 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 128, 3)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_83 (Conv3D)  │ (None, 128, 128,  │      1,312 │ input_layer_2[0]… │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 128, 128,  │          0 │ conv3d_83[0][0]   │
# │ (Dropout)           │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_84 (Conv3D)  │ (None, 128, 128,  │      6,928 │ dropout_18[0][0]  │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_8     │ (None, 64, 64,    │          0 │ conv3d_84[0][0]   │
# │ (MaxPooling3D)      │ 64, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_85 (Conv3D)  │ (None, 64, 64,    │     13,856 │ max_pooling3d_8[… │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 64, 64,    │          0 │ conv3d_85[0][0]   │
# │ (Dropout)           │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_86 (Conv3D)  │ (None, 64, 64,    │     27,680 │ dropout_19[0][0]  │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_9     │ (None, 32, 32,    │          0 │ conv3d_86[0][0]   │
# │ (MaxPooling3D)      │ 32, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_87 (Conv3D)  │ (None, 32, 32,    │     55,360 │ max_pooling3d_9[… │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 32, 32,    │          0 │ conv3d_87[0][0]   │
# │ (Dropout)           │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_88 (Conv3D)  │ (None, 32, 32,    │    110,656 │ dropout_20[0][0]  │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_10    │ (None, 16, 16,    │          0 │ conv3d_88[0][0]   │
# │ (MaxPooling3D)      │ 16, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_89 (Conv3D)  │ (None, 16, 16,    │    221,312 │ max_pooling3d_10… │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 16, 16,    │          0 │ conv3d_89[0][0]   │
# │ (Dropout)           │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_90 (Conv3D)  │ (None, 16, 16,    │    442,496 │ dropout_21[0][0]  │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_11    │ (None, 8, 8, 8,   │          0 │ conv3d_90[0][0]   │
# │ (MaxPooling3D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_91 (Conv3D)  │ (None, 8, 8, 8,   │    884,992 │ max_pooling3d_11… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 8, 8, 8,   │          0 │ conv3d_91[0][0]   │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_92 (Conv3D)  │ (None, 8, 8, 8,   │  1,769,728 │ dropout_22[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_8  │ (None, 16, 16,    │    262,272 │ conv3d_92[0][0]   │
# │ (Conv3DTranspose)   │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 16, 16,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 16, 256)          │            │ conv3d_90[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_93 (Conv3D)  │ (None, 16, 16,    │    884,864 │ concatenate_8[0]… │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 16, 16,    │          0 │ conv3d_93[0][0]   │
# │ (Dropout)           │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_94 (Conv3D)  │ (None, 16, 16,    │    442,496 │ dropout_23[0][0]  │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_9  │ (None, 32, 32,    │     65,600 │ conv3d_94[0][0]   │
# │ (Conv3DTranspose)   │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 32, 32,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 32, 128)          │            │ conv3d_88[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_95 (Conv3D)  │ (None, 32, 32,    │    221,248 │ concatenate_9[0]… │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 32, 32,    │          0 │ conv3d_95[0][0]   │
# │ (Dropout)           │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_96 (Conv3D)  │ (None, 32, 32,    │    110,656 │ dropout_24[0][0]  │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_10 │ (None, 64, 64,    │     16,416 │ conv3d_96[0][0]   │
# │ (Conv3DTranspose)   │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 64, 64,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 64, 64)           │            │ conv3d_86[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_97 (Conv3D)  │ (None, 64, 64,    │     55,328 │ concatenate_10[0… │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 64, 64,    │          0 │ conv3d_97[0][0]   │
# │ (Dropout)           │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_98 (Conv3D)  │ (None, 64, 64,    │     27,680 │ dropout_25[0][0]  │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_11 │ (None, 128, 128,  │      4,112 │ conv3d_98[0][0]   │
# │ (Conv3DTranspose)   │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 128, 128,  │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 128, 32)          │            │ conv3d_84[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_99 (Conv3D)  │ (None, 128, 128,  │     13,840 │ concatenate_11[0… │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 128, 128,  │          0 │ conv3d_99[0][0]   │
# │ (Dropout)           │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_100 (Conv3D) │ (None, 128, 128,  │      6,928 │ dropout_26[0][0]  │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_101 (Conv3D) │ (None, 128, 128,  │         68 │ conv3d_100[0][0]  │
# │                     │ 128, 4)           │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,645,828 (21.54 MB)
#  Trainable params: 5,645,828 (21.54 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# (None, 128, 128, 128, 3)
# (None, 128, 128, 128, 4)

# %%
steps_per_epoch = len(train_img_list)//batch_size
val_steps_per_epoch = len(val_img_list)//batch_size


model = r2_unet_3d(IMG_HEIGHT=128,
                          IMG_WIDTH=128,
                          IMG_DEPTH=128,
                          IMG_CHANNELS=3,
                          num_classes=4)

model.compile(optimizer = optim, loss=total_loss, metrics=metrics)
print(model.summary())

print(model.input_shape)
print(model.output_shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 steps_per_epoch = len(train_img_list)//batch_size
#       2 val_steps_per_epoch = len(val_img_list)//batch_size
#       5 model = r2_unet_3d(IMG_HEIGHT=128,
#       6                           IMG_WIDTH=128,
#       7                           IMG_DEPTH=128,
#       8                           IMG_CHANNELS=3,
#       9                           num_classes=4)
#
# NameError: name 'train_img_list' is not defined

# %%
history=model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=10,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )
model.save('brats_3d.hdf5')
# Out:
# Epoch 1/10
# C:\Users\clari\AppData\Roaming\Python\Python312\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_41']
# Received: inputs=Tensor(shape=(None, 128, 128, 128, 3))
#   warnings.warn(msg)
#  17/129 ━━━━━━━━━━━━━━━━━━━━ 43:18 23s/step - accuracy: 0.7902 - iou_score: 0.1069 - loss: 0.9911

# %%
# Manually recreate history
history = {
    'accuracy': [0.6848, 0.9408, 0.9436, 0.9492, 0.9429, 0.9615, 0.9667, 0.9673, 0.9696, 0.9722],
    'val_accuracy': [0.9482, 0.8581, 0.9072, 0.8953, 0.9501, 0.9568, 0.9444, 0.9567, 0.9538, 0.9443],
    'loss': [0.9799, 0.9344, 0.9214, 0.9104, 0.8990, 0.8807, 0.8699, 0.8666, 0.8615, 0.8540],
    'val_loss': [0.9409, 0.9364, 0.9224, 0.9116, 0.8868, 0.8795, 0.8857, 0.8762, 0.8785, 0.8825]
}

# %%
import matplotlib.pyplot as plt

# Extract values
loss = history['loss']
val_loss = history['val_loss']
epochs = range(1, len(loss) + 1)

# Plot training and validation loss
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Extract values
acc = history['accuracy']
val_acc = history['val_accuracy']

# Plot training and validation accuracy
plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.models import Model
from keras.layers import Input, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, BatchNormalization, Dropout, Lambda, Add
from keras.optimizers import Adam
from keras.metrics import MeanIoU

def recurrent_block_3d(input_tensor, filters, kernel_size=3, recur_num=2):
    """
    Create a recurrent convolutional block for 3D data
    """
    conv = Conv3D(filters, kernel_size, padding='same', kernel_initializer='he_uniform')(input_tensor)
    conv = BatchNormalization()(conv)
    
    # Recurrent connections
    for _ in range(recur_num):
        conv_res = Conv3D(filters, kernel_size, padding='same', kernel_initializer='he_uniform')(conv)
        conv_res = BatchNormalization()(conv_res)
        conv_res = Add()([conv_res, conv])  # Residual connection
        conv = conv_res
    
    return conv

def residual_recurrent_block_3d(input_tensor, filters, kernel_size=3, recur_num=2):
    """
    Create a residual recurrent block with skip connection
    """
    # Shortcut connection
    shortcut = Conv3D(filters, 1, padding='same', kernel_initializer='he_uniform')(input_tensor)
    
    # Recurrent block
    conv = recurrent_block_3d(input_tensor, filters, kernel_size, recur_num)
    conv = recurrent_block_3d(conv, filters, kernel_size, recur_num)
    
    # Add skip connection
    output = Add()([conv, shortcut])
    return output

def r2_unet_3d(IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS, num_classes, recur_num=2):
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS))
    s = inputs

    # Contraction path
    c1 = residual_recurrent_block_3d(s, 16, recur_num=recur_num)
    p1 = MaxPooling3D((2, 2, 2))(c1)
    p1 = Dropout(0.1)(p1)

    c2 = residual_recurrent_block_3d(p1, 32, recur_num=recur_num)
    p2 = MaxPooling3D((2, 2, 2))(c2)
    p2 = Dropout(0.1)(p2)

    c3 = residual_recurrent_block_3d(p2, 64, recur_num=recur_num)
    p3 = MaxPooling3D((2, 2, 2))(c3)
    p3 = Dropout(0.2)(p3)

    c4 = residual_recurrent_block_3d(p3, 128, recur_num=recur_num)
    p4 = MaxPooling3D((2, 2, 2))(c4)
    p4 = Dropout(0.2)(p4)

    # Bridge
    c5 = residual_recurrent_block_3d(p4, 256, recur_num=recur_num)
    c5 = Dropout(0.3)(c5)

    # Expansion path
    u6 = Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])  # Skip connection 1
    c6 = residual_recurrent_block_3d(u6, 128, recur_num=recur_num)
    c6 = Dropout(0.2)(c6)

    u7 = Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])  # Skip connection 2
    c7 = residual_recurrent_block_3d(u7, 64, recur_num=recur_num)
    c7 = Dropout(0.2)(c7)

    u8 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])  # Skip connection 3
    c8 = residual_recurrent_block_3d(u8, 32, recur_num=recur_num)
    c8 = Dropout(0.1)(c8)

    u9 = Conv3DTranspose(16, (2, 2, 2), strides=(2, 2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])  # Skip connection 4
    c9 = residual_recurrent_block_3d(u9, 16, recur_num=recur_num)
    c9 = Dropout(0.1)(c9)

    outputs = Conv3D(num_classes, (1, 1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    model.summary()
    
    return model

# Test the model
if __name__ == "__main__":
    model = r2_unet_3d(128, 128, 128, 3, 4, recur_num=2)
    print(model.input_shape)
    print(model.output_shape)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 128, 3)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_1 (Conv3D)   │ (None, 128, 128,  │      1,312 │ input_layer[0][0] │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │         64 │ conv3d_1[0][0]    │
# │ (BatchNormalizatio… │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_2 (Conv3D)   │ (None, 128, 128,  │      6,928 │ batch_normalizat… │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv3d_2[0][0]    │
# │ (BatchNormalizatio… │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128, 16)          │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_3 (Conv3D)   │ (None, 128, 128,  │      6,928 │ add[0][0]         │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv3d_3[0][0]    │
# │ (BatchNormalizatio… │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128, 16)          │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_4 (Conv3D)   │ (None, 128, 128,  │      6,928 │ add_1[0][0]       │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv3d_4[0][0]    │
# │ (BatchNormalizatio… │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_5 (Conv3D)   │ (None, 128, 128,  │      6,928 │ batch_normalizat… │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv3d_5[0][0]    │
# │ (BatchNormalizatio… │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128, 16)          │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_6 (Conv3D)   │ (None, 128, 128,  │      6,928 │ add_2[0][0]       │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv3d_6[0][0]    │
# │ (BatchNormalizatio… │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128, 16)          │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d (Conv3D)     │ (None, 128, 128,  │         64 │ input_layer[0][0] │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 128, 128,  │          0 │ add_3[0][0],      │
# │                     │ 128, 16)          │            │ conv3d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d       │ (None, 64, 64,    │          0 │ add_4[0][0]       │
# │ (MaxPooling3D)      │ 64, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64, 64,    │          0 │ max_pooling3d[0]… │
# │                     │ 64, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_8 (Conv3D)   │ (None, 64, 64,    │     13,856 │ dropout[0][0]     │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv3d_8[0][0]    │
# │ (BatchNormalizatio… │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_9 (Conv3D)   │ (None, 64, 64,    │     27,680 │ batch_normalizat… │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv3d_9[0][0]    │
# │ (BatchNormalizatio… │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64, 32)           │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_10 (Conv3D)  │ (None, 64, 64,    │     27,680 │ add_5[0][0]       │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv3d_10[0][0]   │
# │ (BatchNormalizatio… │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64, 32)           │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_11 (Conv3D)  │ (None, 64, 64,    │     27,680 │ add_6[0][0]       │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv3d_11[0][0]   │
# │ (BatchNormalizatio… │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_12 (Conv3D)  │ (None, 64, 64,    │     27,680 │ batch_normalizat… │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv3d_12[0][0]   │
# │ (BatchNormalizatio… │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64, 32)           │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_13 (Conv3D)  │ (None, 64, 64,    │     27,680 │ add_7[0][0]       │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv3d_13[0][0]   │
# │ (BatchNormalizatio… │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64, 32)           │            │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_7 (Conv3D)   │ (None, 64, 64,    │        544 │ dropout[0][0]     │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 64, 64,    │          0 │ add_8[0][0],      │
# │                     │ 64, 32)           │            │ conv3d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_1     │ (None, 32, 32,    │          0 │ add_9[0][0]       │
# │ (MaxPooling3D)      │ 32, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling3d_1[… │
# │                     │ 32, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_15 (Conv3D)  │ (None, 32, 32,    │     55,360 │ dropout_1[0][0]   │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv3d_15[0][0]   │
# │ (BatchNormalizatio… │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_16 (Conv3D)  │ (None, 32, 32,    │    110,656 │ batch_normalizat… │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv3d_16[0][0]   │
# │ (BatchNormalizatio… │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32, 64)           │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_17 (Conv3D)  │ (None, 32, 32,    │    110,656 │ add_10[0][0]      │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv3d_17[0][0]   │
# │ (BatchNormalizatio… │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32, 64)           │            │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_18 (Conv3D)  │ (None, 32, 32,    │    110,656 │ add_11[0][0]      │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv3d_18[0][0]   │
# │ (BatchNormalizatio… │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_19 (Conv3D)  │ (None, 32, 32,    │    110,656 │ batch_normalizat… │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv3d_19[0][0]   │
# │ (BatchNormalizatio… │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32, 64)           │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_20 (Conv3D)  │ (None, 32, 32,    │    110,656 │ add_12[0][0]      │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv3d_20[0][0]   │
# │ (BatchNormalizatio… │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32, 64)           │            │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_14 (Conv3D)  │ (None, 32, 32,    │      2,112 │ dropout_1[0][0]   │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 32, 32,    │          0 │ add_13[0][0],     │
# │                     │ 32, 64)           │            │ conv3d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_2     │ (None, 16, 16,    │          0 │ add_14[0][0]      │
# │ (MaxPooling3D)      │ 16, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling3d_2[… │
# │                     │ 16, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_22 (Conv3D)  │ (None, 16, 16,    │    221,312 │ dropout_2[0][0]   │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv3d_22[0][0]   │
# │ (BatchNormalizatio… │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_23 (Conv3D)  │ (None, 16, 16,    │    442,496 │ batch_normalizat… │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv3d_23[0][0]   │
# │ (BatchNormalizatio… │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16, 128)          │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_24 (Conv3D)  │ (None, 16, 16,    │    442,496 │ add_15[0][0]      │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv3d_24[0][0]   │
# │ (BatchNormalizatio… │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16, 128)          │            │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_25 (Conv3D)  │ (None, 16, 16,    │    442,496 │ add_16[0][0]      │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv3d_25[0][0]   │
# │ (BatchNormalizatio… │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_26 (Conv3D)  │ (None, 16, 16,    │    442,496 │ batch_normalizat… │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv3d_26[0][0]   │
# │ (BatchNormalizatio… │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16, 128)          │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_27 (Conv3D)  │ (None, 16, 16,    │    442,496 │ add_17[0][0]      │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv3d_27[0][0]   │
# │ (BatchNormalizatio… │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16, 128)          │            │ add_17[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_21 (Conv3D)  │ (None, 16, 16,    │      8,320 │ dropout_2[0][0]   │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 16, 16,    │          0 │ add_18[0][0],     │
# │                     │ 16, 128)          │            │ conv3d_21[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_3     │ (None, 8, 8, 8,   │          0 │ add_19[0][0]      │
# │ (MaxPooling3D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 8, 8, 8,   │          0 │ max_pooling3d_3[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_29 (Conv3D)  │ (None, 8, 8, 8,   │    884,992 │ dropout_3[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 8,   │      1,024 │ conv3d_29[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_30 (Conv3D)  │ (None, 8, 8, 8,   │  1,769,728 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 8,   │      1,024 │ conv3d_30[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 8, 8, 8,   │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_31 (Conv3D)  │ (None, 8, 8, 8,   │  1,769,728 │ add_20[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 8,   │      1,024 │ conv3d_31[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 8, 8, 8,   │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ add_20[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_32 (Conv3D)  │ (None, 8, 8, 8,   │  1,769,728 │ add_21[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 8,   │      1,024 │ conv3d_32[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_33 (Conv3D)  │ (None, 8, 8, 8,   │  1,769,728 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 8,   │      1,024 │ conv3d_33[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 8, 8, 8,   │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_34 (Conv3D)  │ (None, 8, 8, 8,   │  1,769,728 │ add_22[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 8,   │      1,024 │ conv3d_34[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 8, 8, 8,   │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ add_22[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_28 (Conv3D)  │ (None, 8, 8, 8,   │     33,024 │ dropout_3[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 8, 8, 8,   │          0 │ add_23[0][0],     │
# │                     │ 256)              │            │ conv3d_28[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 8, 8, 8,   │          0 │ add_24[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose    │ (None, 16, 16,    │    262,272 │ dropout_4[0][0]   │
# │ (Conv3DTranspose)   │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 16, 256)          │            │ add_19[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_36 (Conv3D)  │ (None, 16, 16,    │    884,864 │ concatenate[0][0] │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv3d_36[0][0]   │
# │ (BatchNormalizatio… │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_37 (Conv3D)  │ (None, 16, 16,    │    442,496 │ batch_normalizat… │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv3d_37[0][0]   │
# │ (BatchNormalizatio… │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16, 128)          │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_38 (Conv3D)  │ (None, 16, 16,    │    442,496 │ add_25[0][0]      │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv3d_38[0][0]   │
# │ (BatchNormalizatio… │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16, 128)          │            │ add_25[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_39 (Conv3D)  │ (None, 16, 16,    │    442,496 │ add_26[0][0]      │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv3d_39[0][0]   │
# │ (BatchNormalizatio… │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_40 (Conv3D)  │ (None, 16, 16,    │    442,496 │ batch_normalizat… │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv3d_40[0][0]   │
# │ (BatchNormalizatio… │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16, 128)          │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_41 (Conv3D)  │ (None, 16, 16,    │    442,496 │ add_27[0][0]      │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv3d_41[0][0]   │
# │ (BatchNormalizatio… │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16, 128)          │            │ add_27[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_35 (Conv3D)  │ (None, 16, 16,    │     32,896 │ concatenate[0][0] │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_29 (Add)        │ (None, 16, 16,    │          0 │ add_28[0][0],     │
# │                     │ 16, 128)          │            │ conv3d_35[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 16, 16,    │          0 │ add_29[0][0]      │
# │                     │ 16, 128)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_1  │ (None, 32, 32,    │     65,600 │ dropout_5[0][0]   │
# │ (Conv3DTranspose)   │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 32, 128)          │            │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_43 (Conv3D)  │ (None, 32, 32,    │    221,248 │ concatenate_1[0]… │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv3d_43[0][0]   │
# │ (BatchNormalizatio… │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_44 (Conv3D)  │ (None, 32, 32,    │    110,656 │ batch_normalizat… │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv3d_44[0][0]   │
# │ (BatchNormalizatio… │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_30 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32, 64)           │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_45 (Conv3D)  │ (None, 32, 32,    │    110,656 │ add_30[0][0]      │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv3d_45[0][0]   │
# │ (BatchNormalizatio… │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_31 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32, 64)           │            │ add_30[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_46 (Conv3D)  │ (None, 32, 32,    │    110,656 │ add_31[0][0]      │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv3d_46[0][0]   │
# │ (BatchNormalizatio… │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_47 (Conv3D)  │ (None, 32, 32,    │    110,656 │ batch_normalizat… │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv3d_47[0][0]   │
# │ (BatchNormalizatio… │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_32 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32, 64)           │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_48 (Conv3D)  │ (None, 32, 32,    │    110,656 │ add_32[0][0]      │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv3d_48[0][0]   │
# │ (BatchNormalizatio… │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_33 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32, 64)           │            │ add_32[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_42 (Conv3D)  │ (None, 32, 32,    │      8,256 │ concatenate_1[0]… │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_34 (Add)        │ (None, 32, 32,    │          0 │ add_33[0][0],     │
# │                     │ 32, 64)           │            │ conv3d_42[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 32, 32,    │          0 │ add_34[0][0]      │
# │                     │ 32, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_2  │ (None, 64, 64,    │     16,416 │ dropout_6[0][0]   │
# │ (Conv3DTranspose)   │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 64, 64)           │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_50 (Conv3D)  │ (None, 64, 64,    │     55,328 │ concatenate_2[0]… │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv3d_50[0][0]   │
# │ (BatchNormalizatio… │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_51 (Conv3D)  │ (None, 64, 64,    │     27,680 │ batch_normalizat… │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv3d_51[0][0]   │
# │ (BatchNormalizatio… │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_35 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64, 32)           │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_52 (Conv3D)  │ (None, 64, 64,    │     27,680 │ add_35[0][0]      │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv3d_52[0][0]   │
# │ (BatchNormalizatio… │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_36 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64, 32)           │            │ add_35[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_53 (Conv3D)  │ (None, 64, 64,    │     27,680 │ add_36[0][0]      │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv3d_53[0][0]   │
# │ (BatchNormalizatio… │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_54 (Conv3D)  │ (None, 64, 64,    │     27,680 │ batch_normalizat… │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv3d_54[0][0]   │
# │ (BatchNormalizatio… │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_37 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64, 32)           │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_55 (Conv3D)  │ (None, 64, 64,    │     27,680 │ add_37[0][0]      │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv3d_55[0][0]   │
# │ (BatchNormalizatio… │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_38 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64, 32)           │            │ add_37[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_49 (Conv3D)  │ (None, 64, 64,    │      2,080 │ concatenate_2[0]… │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_39 (Add)        │ (None, 64, 64,    │          0 │ add_38[0][0],     │
# │                     │ 64, 32)           │            │ conv3d_49[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64, 64,    │          0 │ add_39[0][0]      │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_3  │ (None, 128, 128,  │      4,112 │ dropout_7[0][0]   │
# │ (Conv3DTranspose)   │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 128, 32)          │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_57 (Conv3D)  │ (None, 128, 128,  │     13,840 │ concatenate_3[0]… │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv3d_57[0][0]   │
# │ (BatchNormalizatio… │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_58 (Conv3D)  │ (None, 128, 128,  │      6,928 │ batch_normalizat… │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv3d_58[0][0]   │
# │ (BatchNormalizatio… │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_40 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128, 16)          │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_59 (Conv3D)  │ (None, 128, 128,  │      6,928 │ add_40[0][0]      │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv3d_59[0][0]   │
# │ (BatchNormalizatio… │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_41 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128, 16)          │            │ add_40[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_60 (Conv3D)  │ (None, 128, 128,  │      6,928 │ add_41[0][0]      │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv3d_60[0][0]   │
# │ (BatchNormalizatio… │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_61 (Conv3D)  │ (None, 128, 128,  │      6,928 │ batch_normalizat… │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv3d_61[0][0]   │
# │ (BatchNormalizatio… │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_42 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128, 16)          │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_62 (Conv3D)  │ (None, 128, 128,  │      6,928 │ add_42[0][0]      │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv3d_62[0][0]   │
# │ (BatchNormalizatio… │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_43 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128, 16)          │            │ add_42[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_56 (Conv3D)  │ (None, 128, 128,  │        528 │ concatenate_3[0]… │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_44 (Add)        │ (None, 128, 128,  │          0 │ add_43[0][0],     │
# │                     │ 128, 16)          │            │ conv3d_56[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 128, 128,  │          0 │ add_44[0][0]      │
# │                     │ 128, 16)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_63 (Conv3D)  │ (None, 128, 128,  │         68 │ dropout_8[0][0]   │
# │                     │ 128, 4)           │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 17,532,308 (66.88 MB)
#  Trainable params: 17,523,476 (66.85 MB)
#  Non-trainable params: 8,832 (34.50 KB)
# (None, 128, 128, 128, 3)
# (None, 128, 128, 128, 4)

# %%
from tensorflow.keras.models import load_model

my_model = load_model('brats_3d.hdf5', compile=False)

# Verify IoU on a batch of images from the test dataset
# Using built-in keras function for IoU
# Only works on TF > 2.0
from keras.metrics import MeanIoU

# %%
my_model = load_model('r2unet2_plus_3d_final_model.hdf5', 
                      compile=False)


#Verify IoU on a batch of images from the test dataset
#Using built in keras function for IoU
#Only works on TF > 2.0
from keras.metrics import MeanIoU

batch_size=8 #Check IoU for a batch of images
test_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
test_image_batch, test_mask_batch = test_img_datagen.__next__()

test_mask_batch_argmax = np.argmax(test_mask_batch, axis=4)
test_pred_batch = my_model.predict(test_image_batch)
test_pred_batch_argmax = np.argmax(test_pred_batch, axis=4)

n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(test_pred_batch_argmax, test_mask_batch_argmax)
print("Mean IoU =", IOU_keras.result().numpy())

#############################################
#Predict on a few test images, one at a time
#Try images: 
img_num = 82

test_img = np.load("BraTS2020_TrainingData/input_data_128/val/images/image_"+str(img_num)+".npy")

test_mask = np.load("BraTS2020_TrainingData/input_data_128/val/masks/mask_"+str(img_num)+".npy")
test_mask_argmax=np.argmax(test_mask, axis=3)

test_img_input = np.expand_dims(test_img, axis=0)
test_prediction = my_model.predict(test_img_input)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]


# print(test_prediction_argmax.shape)
# print(test_mask_argmax.shape)
# print(np.unique(test_prediction_argmax))


#Plot individual slices from test predictions for verification
from matplotlib import pyplot as plt
import random

#n_slice=random.randint(0, test_prediction_argmax.shape[2])
n_slice = 55
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,n_slice,1], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,n_slice])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:, n_slice])
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 45s 45s/step
# Mean IoU = 0.5840349
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step

# %% [markdown]
# Epoch 1/5
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7710s 60s/step - accuracy: 0.5063 - iou_score: 0.1539 - loss: 1.0662 - val_accuracy: 0.4366 - val_iou_score: 0.1344 - val_loss: 1.4531
# Epoch 2/5
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7542s 58s/step - accuracy: 0.9505 - iou_score: 0.3775 - loss: 0.9024 - val_accuracy: 0.9520 - val_iou_score: 0.2719 - val_loss: 0.9569
# Epoch 3/5
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6964s 54s/step - accuracy: 0.9695 - iou_score: 0.4862 - loss: 0.8653 - val_accuracy: 0.9428 - val_iou_score: 0.4944 - val_loss: 0.8734
# Epoch 4/5
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6905s 54s/step - accuracy: 0.9629 - iou_score: 0.4396 - loss: 0.8829 - val_accuracy: 0.9543 - val_iou_score: 0.3518 - val_loss: 0.9294
# Epoch 5/5
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7041s 55s/step - accuracy: 0.9760 - iou_score: 0.5548 - loss: 0.8451 - val_accuracy: 0.9361 - val_iou_score: 0.4877 - val_loss: 0.8814
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import matplotlib.pyplot as plt

# Manually recreate history from the provided data
history = {
    'accuracy': [0.5063, 0.9505, 0.9695, 0.9629, 0.9760],
    'val_accuracy': [0.4366, 0.9520, 0.9428, 0.9543, 0.9361],
    'iou_score': [0.1539, 0.3775, 0.4862, 0.4396, 0.5548],
    'val_iou_score': [0.1344, 0.2719, 0.4944, 0.3518, 0.4877],
    'loss': [1.0662, 0.9024, 0.8653, 0.8829, 0.8451],
    'val_loss': [1.4531, 0.9569, 0.8734, 0.9294, 0.8814]
}

# Extract values for plotting
epochs = range(1, len(history['loss']) + 1)

# Plot training and validation loss
plt.figure(figsize=(5, 5))
plt.plot(epochs, history['loss'], 'y', label='Training loss')
plt.plot(epochs, history['val_loss'], 'r', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(5, 5))
plt.plot(epochs, history['accuracy'], 'y', label='Training Accuracy')
plt.plot(epochs, history['val_accuracy'], 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation IoU score
plt.figure(figsize=(5, 5))
plt.plot(epochs, history['iou_score'], 'y', label='Training IoU Score')
plt.plot(epochs, history['val_iou_score'], 'r', label='Validation IoU Score')
plt.title('Training and Validation IoU Score')
plt.xlabel('Epochs')
plt.ylabel('IoU Score')
plt.legend()
plt.show()
